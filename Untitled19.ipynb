# %%
l = [3.4,5,7,8,4,6.8]
print(l)
import numpy as np

a = np.array(["hello","hi",4])
print(a)
# Out:
# [3.4, 5, 7, 8, 4, 6.8]
# ['hello' 'hi' '4']

# %%
import numpy as np

a = np.array([[2,3],[5,6]])
#print(np.ndim(a))

#print(a[1][0])

for i in np.ndenumerate(a):
    print(i)
# Out:
# ((0, 0), 2)
# ((0, 1), 3)
# ((1, 0), 5)
# ((1, 1), 6)

# %%
import numpy as np

a = np.array([[1,2],[3,4]])
print(a)
#b = np.array([[5,6],[7,8]])
# print(a)
# print(b)
#print(a+b)
print(np.sum(a, axis = 1)) #0 = vertical axis, 1 = horizontal axis
# Out:
# [[1 2]
#  [3 4]]
# [3 7]

# %%
import numpy as np

a = np.loadtxt("C:/Users/WsCube Tech/Desktop/Excel Course/datasets/sales.csv",delimiter = ",",skiprows = 1)
print(a)
z = np.product(a, axis = 1)
print(z)
print(np.sum(z))
# Out:
# [[ 2. 84.]
#  [ 6. 56.]
#  [ 3. 44.]
#  [ 6. 58.]
#  [ 6. 93.]
#  [ 7. 55.]
#  [ 3. 66.]
#  [ 6. 56.]
#  [ 8. 89.]
#  [ 3. 35.]
#  [ 6. 24.]]
# [168. 336. 132. 348. 558. 385. 198. 336. 712. 105. 144.]
# 3422.0

# %%
import numpy as np

a = np.array([[1,2],[3,4]])
b = np.array([[3,4],[5,6]])
print(np.subtract(a,b))
# Out:
# [[-2 -2]
#  [-2 -2]]

# %%
#discriptive
import numpy as np
import statistics as stats

a = np.array([1,2,3,3,3,4,4]) 
print(np.mean(a)) #average (sum of elements/number of elements)
print(np.median(a)) # central value(after sorting)
print(stats.mode(a))
# Out:
# 2.857142857142857
# 3.0
# 3

# %%
import numpy as np
import statistics as stats

a = np.loadtxt("reviews.txt")
print(a)
print(np.mean(a))
print(np.median(a))
print(stats.mode(a))
print(np.percentile(a,50))
print(np.range(a))
# Out:
# [4.5 3.4 2.  4.  3.8 5.  3.  4.  4.5 5.  4.  3.4 4.4]
# 3.923076923076923
# 4.0
# 4.0
# 4.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 10
#       8 print(stats.mode(a))
#       9 print(np.percentile(a,50))
# ---> 10 print(np.range(a))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'range'

# %%
a = int(input("enter name: "))
b = int(input("enter num"))

if a > 1000:
    print("incorrect data")
else:
    print(a*b)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 a = int(input("enter name: "))
#       2 b = int(input("enter num"))
#       4 if a > 1000:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1191, in Kernel.raw_input(self, prompt)
#    1189     msg = "raw_input was called, but this frontend does not support input requests."
#    1190     raise StdinNotImplementedError(msg)
# -> 1191 return self._input_request(
#    1192     str(prompt),
#    1193     self._parent_ident["shell"],
#    1194     self.get_parent("shell"),
#    1195     password=False,
#    1196 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1234, in Kernel._input_request(self, prompt, ident, parent, password)
#    1231 except KeyboardInterrupt:
#    1232     # re-raise KeyboardInterrupt, to truncate traceback
#    1233     msg = "Interrupted by user"
# -> 1234     raise KeyboardInterrupt(msg) from None
#    1235 except Exception:
#    1236     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
math=5
science=7
fictional=10
novels=30

username = "ayushi@gmail.com"
password = "1234"

print ("ENTER YOUR LOGIN DETAILS BELOW")

u = input ("Enter Username : ")
p = input("Enter Password : ")

if u==username.lower() and p==password :
    print ("login successful")
    while True:
        print ("\n\n******************* WELCOME TO LIBRARY *****************************\n\n")
        print ("\nAvailabe maths books in library : ",math)
        print ("\nAvailabe science books in library : ",science)
        print ("\nAvailabe fiction books in library : ",fictional)
        print ("\nAvailabe novels in library : ",novels)
        
        a=input("""\nYou want to borrow book or you want to return the borrowed book? 
        \npress r to return book or press b to borrow book : """)
        
        if a.lower() == "b":
            borrower= input ("\nEnter borrower's name : ")
            choice= int(input ("""\nwhich kind of books do you want to borrow : 
               \n Type 1 to borrow math book
               \n Type 2 to borrow science book
               \n press 3 to borrow fictional book
               \n press 4 to borrow novel
               \n Enter your book choice: """))
            if choice==1:
                num_book=int(input("\nHow many math book do you want to borrow? "))
                if num_book<=math:
                    math-=num_book
                    print(f"\n{borrower}, you have successfully borrowed {num_book} math book!")
                    print ("\nAvailable math book after borrowing : ",math)
                else:
                    print(f"\nSorry, only {math} math book left.")
            elif choice==2:
                num_book=int(input("\nHow many science book do you want to borrow? "))
                if num_book<=science:
                    science-=num_book
                    print(f"\n{borrower}, you have successfully borrowed {num_book} science book!")
                    print ("\nAvailable science book after borrowing : ",science)
                else:
                    print(f"\nSorry,{science} science book left.")
            
            elif choice==3:
                num_book=int(input("\nHow many fictional book do you want to borrow? "))
                if num_book<=fictional:
                    fictional-=num_book
                    print(f"\n{borrower}, you have successfully borrowed {num_book} fictional book!")
                    print ("\nAvailable fictional book after borrowing : ",fictional)
                else:
                    print(f"\nSorry,{fictional} fictional book left.")
            elif choice==4:
                num_book=int(input("\nHow many novel do you want to borrow? "))
                if num_book<=novels:
                    novels-=num_book
                    print(f"\n{borrower}, you have successfully borrowed {num_book} novel(s)!")
                    print ("\nAvailable novels after borrowing : ",novels)
                else:
                    print(f"\nSorry,{novels} novel left.")
        elif a.lower() == "r":
            choice= int(input ("""\nWhich kind of book you want to return : 
               \n Type 1 to return math book
               \n Type 2 to return science book
               \n Press 3 to return fictional book
               \n Press 4 to return novel
               \n Enter your book choice: """))
        if choice==1:
            num_book=int(input("\nHow many math book do you want to return? "))
            math+=num_book
            print(f"\n{num_book} math book have been returned successfully!")
            print ("\nAvailable math book after return :" ,math)
        else:
            print ("\nInvalid input. Please try again.")
        
        if choice==2:
            num_book=int(input("\nHow many science book do you want to return? "))
            science+=num_book
            print(f"\n{num_book} science book have been returned successfully!")
            print ("\nAvailable science book after return :" ,science)
        else:
            print ("\nInvalid input. Please try again.")
        
        if choice==3:
            num_book=int(input("\nHow many fictional book do you want to return? "))
            fictional+=num_book
            print(f"\n{num_book} fictional book have been returned successfully!")
            print ("\nAvailable fictional book after return :" ,fictional)
        else:
            print ("\nInvalid input. Please try again.")
        
        if choice==4:
            num_book=int(input("\nHow many novel do you want to return? "))
            fictional+=num_book
            print(f"\n{num_book} novel​ have been returned successfully!")
            print ("\nAvailable fictional book novelafter return :" ,novel)
        else:
            print ("\nInvalid input. Please try again.")
else :
    print ("Login unsuccessful. Try again later")
# Out:
# ENTER YOUR LOGIN DETAILS BELOW
# Enter Username : ayushi@gmail.com
# Enter Password : 1234
# login successful
#
#
# ******************* WELCOME TO LIBRARY *****************************
#
#
#
# Availabe maths books in library :  5
#
# Availabe science books in library :  7
#
# Availabe fiction books in library :  10
#
# Availabe novels in library :  30
#
# You want to borrow book or you want to return the borrowed book?
#
# press r to return book or press b to borrow book : b
#
# Enter borrower's name : ayushi
#
# which kind of books do you want to borrow :
#
#  Type 1 to borrow math book
#
#  Type 2 to borrow science book
#
#  press 3 to borrow fictional book
#
#  press 4 to borrow novel
#
#  Enter your book choice: 1
#
# How many math book do you want to borrow? 5
#
# ayushi, you have successfully borrowed 5 math book!
#
# Available math book after borrowing :  0
#
# How many math book do you want to return? 6
#
# 6 math book have been returned successfully!
#
# Available math book after return : 6
#
# Invalid input. Please try again.
#
# Invalid input. Please try again.
#
# Invalid input. Please try again.
#
#
# ******************* WELCOME TO LIBRARY *****************************
#
#
#
# Availabe maths books in library :  6
#
# Availabe science books in library :  7
#
# Availabe fiction books in library :  10
#
# Availabe novels in library :  30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 23
#      20 print ("\nAvailabe fiction books in library : ",fictional)
#      21 print ("\nAvailabe novels in library : ",novels)
# ---> 23 a=input("""\nYou want to borrow book or you want to return the borrowed book?
#      24 \npress r to return book or press b to borrow book : """)
#      26 if a.lower() == "b":
#      27     borrower= input ("\nEnter borrower's name : ")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1191, in Kernel.raw_input(self, prompt)
#    1189     msg = "raw_input was called, but this frontend does not support input requests."
#    1190     raise StdinNotImplementedError(msg)
# -> 1191 return self._input_request(
#    1192     str(prompt),
#    1193     self._parent_ident["shell"],
#    1194     self.get_parent("shell"),
#    1195     password=False,
#    1196 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1234, in Kernel._input_request(self, prompt, ident, parent, password)
#    1231 except KeyboardInterrupt:
#    1232     # re-raise KeyboardInterrupt, to truncate traceback
#    1233     msg = "Interrupted by user"
# -> 1234     raise KeyboardInterrupt(msg) from None
#    1235 except Exception:
#    1236     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
Books={"maths":10, "science":12, "socialscience":15}
while True:
    Username=input("Username:" )
    Password=input("Password:" )
    print("")
    Credentials={"Ayushi":"Ayushi@123" ,"Happy":"Happy@123"}
    if Username in Credentials.keys():
        if Password == Credentials[Username]:
            while True:
                print("Welcome to the Library", Username)
                print("")
                print(
"""Press 1 for issuing
Press 2 for return or add more books
Press 3 for balance & return to home page""")

                C = int(input("Enter Your Choice:"))
                if C == 1:
                    print(Books)
                    d = input("Enter Your Book Choice:").lower()
                    if d in Books.keys():
                        n = int(input("Enter quantity of Books:"))
                        if n <= Books[d]:
                            Books[d] -= n
                        else:
                            print("We only have following balance of", d, Books[d])
                    else:
                        print(d, "Book is currently un-available")
                elif C == 2:
                    a = input("Which book you want to return:")
                    b = int(input("Enter quantity of Books:"))
                    if a in Books.keys():
                        Books[a] += b
                    else:
                        Books[a] = b
                    print(Books)

                elif C == 3:
                    print(Books)
                    print("Thanks & regards, Have a nice day", Username)
                    break
        else:
            print("Invalid Password")

    else:
        print("You're not our member")
# Out:
# Username:Ayushi
# Password:Ayushi@123
#
# Welcome to the Library Ayushi
#
# Press 1 for issuing
# Press 2 for return or add more books
# Press 3 for balance & return to home page
# Enter Your Choice:1
# {'maths': 10, 'science': 12, 'socialscience': 15}
# Enter Your Book Choice:hindi
# hindi Book is currently un-available
# Welcome to the Library Ayushi
#
# Press 1 for issuing
# Press 2 for return or add more books
# Press 3 for balance & return to home page
# Enter Your Choice:1
# {'maths': 10, 'science': 12, 'socialscience': 15}
# Enter Your Book Choice:math
# math Book is currently un-available
# Welcome to the Library Ayushi
#
# Press 1 for issuing
# Press 2 for return or add more books
# Press 3 for balance & return to home page
# Enter Your Choice:1
# {'maths': 10, 'science': 12, 'socialscience': 15}
# Enter Your Book Choice:maths
# Enter quantity of Books:5
# Welcome to the Library Ayushi
#
# Press 1 for issuing
# Press 2 for return or add more books
# Press 3 for balance & return to home page
# Enter Your Choice:2
# Which book you want to return:maths
# Enter quantity of Books:7
# {'maths': 12, 'science': 12, 'socialscience': 15}
# Welcome to the Library Ayushi
#
# Press 1 for issuing
# Press 2 for return or add more books
# Press 3 for balance & return to home page
# Enter Your Choice:3
# {'maths': 12, 'science': 12, 'socialscience': 15}
# Thanks & regards, Have a nice day Ayushi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 3
#       1 Books={"maths":10, "science":12, "socialscience":15}
#       2 while True:
# ----> 3     Username=input("Username:" )
#       4     Password=input("Password:" )
#       5     print("")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1191, in Kernel.raw_input(self, prompt)
#    1189     msg = "raw_input was called, but this frontend does not support input requests."
#    1190     raise StdinNotImplementedError(msg)
# -> 1191 return self._input_request(
#    1192     str(prompt),
#    1193     self._parent_ident["shell"],
#    1194     self.get_parent("shell"),
#    1195     password=False,
#    1196 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1234, in Kernel._input_request(self, prompt, ident, parent, password)
#    1231 except KeyboardInterrupt:
#    1232     # re-raise KeyboardInterrupt, to truncate traceback
#    1233     msg = "Interrupted by user"
# -> 1234     raise KeyboardInterrupt(msg) from None
#    1235 except Exception:
#    1236     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
seats={"Normal_seats": 130,"Recliners": 20}
while True:
    from datetime import datetime
    now = datetime.now()
    current_time1 = now.strftime("%H:%M:%S")
    current_time = now.strftime("%H")
    current_time = int(current_time)
    total = 0
    Name = input("enter your name:")
    print(f"Welcome To Hogwarts Theater {Name}")
    print(f"it's {current_time1}")
    if current_time in range(0, 12):
        print("Good morning")
    elif current_time in range(12, 16):
        print("Good afternoon")
    elif current_time in range(16, 23):
        print("Good Evening")

    while True:
        Seat_choice = input('If you want Recliners 350rs press 1, For Normal_seats 250rs press 2: ')
        if seats["Normal_seats"] == 0 and seats["Recliners"] == 0:
            print(f"oops, Sorry {Name} houseful")
            print("Final Total:", total)
            break

        elif Seat_choice == '1':
            if seats["Recliners"] > 0:
                print(f'You have chosen Recliners, {seats["Recliners"]} Recliners left')
                seat = int(input("How many seats you want:"))
                if seat<=seats["Recliners"]:
                    seats["Recliners"] -= seat
                    total = total + seat * 350
                    x = input('Need anything else: (press 1 for any other seat, 2 for Snacks,say N if done):')
                    if x != "1" and x != "2":
                        print("ok nothing added more, Final Total:", total)
                        break
                    elif x == "2":
                        print("Yayy!!, Meal added")
                        total = total + 150
                        print("Final Total including meal:", total)
                        break
                    elif x == "1":
                        continue
                else:
                    print(f'Sorry we have only, {seats["Recliners"]} Recliners, you need more than our capacity')
            else:
                    print("No more recliners")
                    print("Final Total:", total)
                    continue
        elif Seat_choice == '2':
            if seats["Normal_seats"] > 0:
                print(f'You have chosen Normal_seats, {seats["Normal_seats"]} Normal_seats left')
                seat = int(input("How many seats you want:"))
                if seat<=seats["Normal_seats"]:
                    seats["Normal_seats"] -= seat
                    total = total + seat * 150
                    x = input('Need anything else: (press 1 for any other seat, 2 for Snacks,say N if done):')
                    if x != "1" and x != "2":
                        print("ok nothing added more, Final Total:", total)
                        break
                    elif x == "2":
                        print("Yayy!!, Meal added")
                        total = total + 150
                        print("Final Total including meal:", total)
                    elif x == "1":
                        continue
                else:
                    print(f'Sorry we have only, {seats["Normal_seats"]} Normal_seats, you need more than our capacity')
            elif seats["Normal_seats"] <= 0:
                print("No more Normal_seats")
                print("Final Total:", total)
                continue
        else:
            print(f"Wrong choice dear {Name},Try again between 1&2")
            continue
# Out:
# enter your name:ayushi
# Welcome To Hogwarts Theater ayushi
# it's 19:38:20
# Good Evening
# If you want Recliners 350rs press 1, For Normal_seats 250rs press 2: 2
# You have chosen Normal_seats, 130 Normal_seats left
# How many seats you want:145
# Sorry we have only, 130 Normal_seats, you need more than our capacity
# If you want Recliners 350rs press 1, For Normal_seats 250rs press 2: 2
# You have chosen Normal_seats, 130 Normal_seats left
# How many seats you want:2
# Need anything else: (press 1 for any other seat, 2 for Snacks,say N if done):2
# Yayy!!, Meal added
# Final Total including meal: 450
# If you want Recliners 350rs press 1, For Normal_seats 250rs press 2: 2
# You have chosen Normal_seats, 128 Normal_seats left
# How many seats you want:0
# Need anything else: (press 1 for any other seat, 2 for Snacks,say N if done):N
# ok nothing added more, Final Total: 450
