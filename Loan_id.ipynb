# %%
import pandas as pd

data = pd.read_excel("PDA - Zappy Loan Data (2).xlsx")
df = pd.DataFrame(data)
print(df)

f_df = df.loc[df['Gender'] == 1]
m_df = df.loc[df['Gender'] == 2]
# Out:
#      Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed  \
# 0       2284       1        0           0         0              0
# 1       2287       2        0           0         1              0
# 2       2288       1        1           2         0              0
# 3       2296       1        0           0         0              0
# 4       2297       1        0           0         1              0
# ..       ...     ...      ...         ...       ...            ...
# 242     2978       2        0           0         1              0
# 243     2979       1        1           3         1              0
# 244     2983       1        1           1         1              0
# 245     2984       1        1           2         1              0
# 246     2990       2        0           0         1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               3902             1666.0         109               333
# ...
